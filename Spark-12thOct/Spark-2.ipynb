# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.0.tar.gz (316.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425344 sha256=dae4f9acffcfc29b8a621474c7c12e8aa13efcd7b63f91e6f9b0096fa613f0fc
#   Stored in directory: /root/.cache/pip/wheels/41/4e/10/c2cf2467f71c678cfc8a6b9ac9241e5e44a01940da8fbb17fc
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.0

# %%
import pyspark
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName('spark').getOrCreate()

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
students=spark.sparkContext.textFile('drive/My Drive/Colab Notebooks/Students.txt')

# %% [markdown]
# Create dataset (text file) with fields like ‘Student Name’, ‘Institute’, ‘Program Name’, and ‘Gender’ and solve following questions

# %%
students.collect()
# Out:
# ['Nidhi MSIS ME F',
#  'Gowthami MSIS ME F',
#  'Imaad MSIS ME M',
#  'Ananya MSIS ME F',
#  'Manthan MSIS ME M',
#  'Nithin MSIS ME M',
#  'Ayeman MIT MTech F',
#  'Vaishnavi MIT MTech F',
#  'Priyanka MIT MTech F',
#  'Prajwal MIT MTech M']

# %%
#Compute number of students from each Institute.
students.map(lambda d:(d.split(' ')[1],1)).reduceByKey(lambda a,b:a+b).collect()
# Out:
# [('MSIS', 6), ('MIT', 4)]

# %%
#Number of students enrolled to any program.
students.map(lambda d:(d.split(' ')[2],1)).reduceByKey(lambda a,b:a+b).collect()
# Out:
# [('ME', 6), ('MTech', 4)]

# %%
#Number of ‘boy’ and ‘girl’ students.
students.map(lambda d:(d.split(' ')[3],1)).reduceByKey(lambda a,b:a+b).collect()
# Out:
# [('F', 6), ('M', 4)]
