               3|       3|            3|  false|         NULL|        1|        ENGINE|                         1|                     7|                 1|      Inner Richmond|(37.7768682293368...|020110330-E14|      2.0|
# |  20110330|   M12|       2003417|Medical Incident|01/11/2002|01/11/2002|               Other|01/11/2002 04:51:...|BALBOA ST/PARK PR...|  SF|  94118|      B07|         31|7145|               3|       3|            3|   true|         NULL|        1|         MEDIC|                         2|                     7|                 1|      Inner Richmond|(37.7768682293368...|020110330-M12|1.8166667|
# +----------+------+--------------+----------------+----------+----------+--------------------+--------------------+--------------------+----+-------+---------+-----------+----+----------------+--------+-------------+-------+-------------+---------+--------------+--------------------------+----------------------+------------------+--------------------+--------------------+-------------+---------+
# only showing top 20 rows

# %%
df=df.withColumn('Date',to_date(col('callDate'),'dd/mm/yyyy')).drop('callDate')

# %%
clean_df=df.withColumn('Year',year(col('Date'))).withColumn('Month',month(col('Date'))).withColumn('Week',weekofyear(col('Date')))
clean_df.show()
# Out:
# +----------+------+--------------+----------------+----------+--------------------+--------------------+--------------------+----+-------+---------+-----------+----+----------------+--------+-------------+-------+-------------+---------+--------------+--------------------------+----------------------+------------------+--------------------+--------------------+-------------+---------+----------+----+-----+----+
# |CallNumber|UnitID|IncidentNumber|        CallType| WatchDate|CallFinalDisposition|       AvailableDtTm|             Address|City|Zipcode|Battalion|StationArea| Box|OriginalPriority|Priority|FinalPriority|ALSUnit|CallTypeGroup|NumAlarms|      UnitType|UnitSequenceInCallDispatch|FirePreventionDistrict|SupervisorDistrict|        Neighborhood|            Location|        RowID|    Delay|      Date|Year|Month|Week|
# +----------+------+--------------+----------------+----------+--------------------+--------------------+--------------------+----+-------+---------+-----------+----+----------------+--------+-------------+-------+-------------+---------+--------------+--------------------------+----------------------+------------------+--------------------+--------------------+-------------+---------+----------+----+-----+----+
# |  20110016|   T13|       2003235|  Structure Fire|01/10/2002|               Other|01/11/2002 01:51:...|2000 Block of CAL...|  SF|  94109|      B04|         38|3362|               3|       3|            3|  false|         NULL|        1|         TRUCK|                         2|                     4|                 5|     Pacific Heights|(37.7895840679362...|020110016-T13|     2.95|2002-01-01|2002|    1|   1|
# |  20110022|   M17|       2003241|Medical Incident|01/10/2002|               Other|01/11/2002 03:01:...|0 Block of SILVER...|  SF|  94124|      B10|         42|6495|               3|       3|            3|   true|         NULL|        1|         MEDIC|                         1|                    10|                10|Bayview Hunters P...|(37.7337623673897...|020110022-M17|      4.7|2002-01-01|2002|    1|   1|
# |  20110023|   M41|       2003242|Medical Incident|01/10/2002|               Other|01/11/2002 02:39:...|MARKET ST/MCALLIS...|  SF|  94102|      B03|         01|1455|               3|       3|            3|   true|         NULL|        1|         MEDIC|                         2|                     3|                 6|          Tenderloin|(37.7811772186856...|020110023-M41|2.4333334|2002-01-01|2002|    1|   1|
# |  20110032|   E11|       2003250|    Vehicle Fire|01/10/2002|               Other|01/11/2002 04:16:...|APPLETON AV/MISSI...|  SF|  94110|      B06|         32|5626|               3|       3|            3|  false|         NULL|        1|        ENGINE|                         1|                     6|                 9|      Bernal Heights|(37.7388432849018...|020110032-E11|      1.5|2002-01-01|2002|    1|   1|
# |  20110043|   B04|       2003259|          Alarms|01/10/2002|               Other|01/11/2002 06:01:...|1400 Block of SUT...|  SF|  94109|      B04|         03|3223|               3|       3|            3|  false|         NULL|        1|         CHIEF|                         2|                     4|                 2|    Western Addition|(37.7872890372638...|020110043-B04|3.4833333|2002-01-01|2002|    1|   1|
# |  20110072|   T08|       2003279|  Structure Fire|01/11/2002|               Other|01/11/2002 08:03:...|  BEALE ST/FOLSOM ST|  SF|  94105|      B03|         35|2122|               3|       3|            3|  false|         NULL|        1|         TRUCK|                         2|                     3|                 6|Financial Distric...|(37.7886866619654...|020110072-T08|     1.75|2002-01-01|2002|    1|   1|
# |  20110125|   E33|       2003301|          Alarms|01/11/2002|               Other|01/11/2002 09:46:...|0 Block of FARALL...|  SF|  94112|      B09|         33|8324|               3|       3|            3|  false|         NULL|        1|        ENGINE|                
# |  20110313|   E32|       2003408|  Structure Fire|01/11/2002|               Other|01/11/2002 04:09:...|700 Block of CAPP ST|  SF|  94110|      B06|         07|5472|               3|       3|            3|   true|         NULL|        1|        ENGINE|                         8|                     6|                 9|             Mission|(37.7547064357942...|020110313-E32|1.8833333|2002-01-01|2002|    1|   1|
# |  20110315|   RC2|       2003409|Medical Incident|01/11/2002|               Other|01/11/2002 04:34:...|200 Block of LAGU...|  SF|  94116|      B08|         20|8635|               3|       3|            3|   true|         NULL|        1|RESCUE CAPTAIN|                         2|                     8|                 7|  West of Twin Peaks|(37.7501117393668...|020110315-RC2|     5.35|2002-01-01|2002|    1|   1|
# |  20110330|   E14|       2003417|Medical Incident|01/11/2002|               Other|01/11/2002 04:51:...|BALBOA ST/PARK PR...|  SF|  94118|      B07|         31|7145|               3|       3|            3|  false|         NULL|        1|        ENGINE|                         1|                     7|                 1|      Inner Richmond|(37.7768682293368...|020110330-E14|      2.0|2002-01-01|2002|    1|   1|
# |  20110330|   M12|       2003417|Medical Incident|01/11/2002|               Other|01/11/2002 04:51:...|BALBOA ST/PARK PR...|  SF|  94118|      B07|         31|7145|               3|       3|            3|   true|         NULL|        1|         MEDIC|                         2|                     7|                 1|      Inner Richmond|(37.7768682293368...|020110330-M12|1.8166667|2002-01-01|2002|    1|   1|
# +----------+------+--------------+----------------+----------+--------------------+--------------------+--------------------+----+-------+---------+-----------+----+----------------+--------+-------------+-------+-------------+---------+--------------+--------------------------+----------------------+------------------+--------------------+--------------------+-------------+---------+----------+----+-----+----+
# only showing top 20 rows

# %%
df.count()
# Out:
# 175296

# %%
 #Get yearly count of fire calls
clean_df.select('Year').groupBy('Year').count().orderBy('Year',ascending=True).show()
# Out:
# +----+-----+
# |Year|count|
# +----+-----+
# |2000| 5459|
# |2001| 7713|
# |2002| 8090|
# |2003| 8499|
# |2004| 8283|
# |2005| 8282|
# |2006| 8174|
# |2007| 8255|
# |2008| 8869|
# |2009| 8789|
# |2010| 9341|
# |2011| 9735|
# |2012| 9674|
# |2013|10020|
# |2014|10775|
# |2015|11458|
# |2016|11609|
# |2017|12135|
# |2018|10136|
# +----+-----+

# %%
#What were all the different types of fire calls in 2018?
clean_df.select('callType').where(col('Year')=='2018').distinct().show(truncate=False)
# Out:
# +-------------------------------+
# |callType                       |
# +-------------------------------+
# |Elevator / Escalator Rescue    |
# |Alarms                         |
# |Odor (Strange / Unknown)       |
# |Citizen Assist / Service Call  |
# |HazMat                         |
# |Vehicle Fire                   |
# |Other                          |
# |Outside Fire                   |
# |Traffic Collision              |
# |Assist Police                  |
# |Gas Leak (Natural and LP Gases)|
# |Water Rescue                   |
# |Electrical Hazard              |
# |Structure Fire                 |
# |Medical Incident               |
# |Fuel Spill                     |
# |Smoke Investigation (Outside)  |
# |Train / Rail Incident          |
# |Explosion                      |
# |Suspicious Package             |
# +-------------------------------+

# %%
#Which week in the year in 2018 had the most fire calls?
fire_calls_2018 = clean_df.filter(col('Year') == 2018)
max_week = fire_calls_2018.groupBy('Week').count()
max_count = max_week.agg({'count': 'max'}).collect()[0][0]
result = max_week.filter(col('count') == max_count).select('Week')
result.show()
# Out:
# +----+
# |Week|
# +----+
# |   1|
# +----+

# %%
#Get monthly count of fire calls based on year
clean_df.groupBy('Year','Month').count().show()
# Out:
# +----+-----+-----+
# |Year|Month|count|
# +----+-----+-----+
# |2018|    1|10136|
# |2008|    1| 8869|
# |2009|    1| 8789|
# |2003|    1| 8499|
# |2014|    1|10775|
# |2005|    1| 8282|
# |2016|    1|11609|
# |2012|    1| 9674|
# |2006|    1| 8174|
# |2002|    1| 8090|
# |2013|    1|10020|
# |2015|    1|11458|
# |2011|    1| 9735|
# |2010|    1| 9341|
# |2017|    1|12135|
# |2001|    1| 7713|
# |2007|    1| 8255|
# |2000|    1| 5459|
# |2004|    1| 8283|
# +----+-----+-----+

# %%
#Give monthly report of fire call types for selected year
selected_year = 2018
filtered_data = clean_df.filter(col('Year') == selected_year)
monthly_report = filtered_data.groupBy('Month', 'CallType').count()
monthly_report.show()
# Out:
# +-----+--------------------+-----+
# |Month|            CallType|count|
# +-----+--------------------+-----+
# |    1|               Other|  114|
# |    1|Train / Rail Inci...|    5|
# |    1|        Vehicle Fire|   28|
# |    1|Odor (Strange / U...|   10|
# |    1|              HazMat|    5|
# |    1|      Structure Fire|  906|
# |    1|          Fuel Spill|   10|
# |    1|Citizen Assist / ...|  113|
# |    1|   Traffic Collision|  433|
# |    1|   Electrical Hazard|   30|
# |    1|Elevator / Escala...|   36|
# |    1|        Water Rescue|   43|
# |    1|        Outside Fire|  153|
# |    1|    Medical Incident| 7004|
# |    1|Gas Leak (Natural...|   69|
# |    1|              Alarms| 1144|
# |    1|Smoke Investigati...|   28|
# |    1|       Assist Police|    1|
# |    1|           Explosion|    1|
# |    1|  Suspicious Package|    3|
# +-----+--------------------+-----+

# %%
#consider month and if particular month then estimate the season
#UDF->user defined function to register all the method calls
def mapSeason(data):
  if 2 < data < 6:
    return 'Spring'
  elif 5 < data <9:
    return 'Summer'
  elif 8 < data < 12:
    return 'Autumn'
  else:
    return 'Winter'
seasonUDF=udf(mapSeason,StringType())
clean_df=clean_df.withColumn('Season',seasonUDF(col('Month')))
clean_df.show()
# Out:
# +----------+------+--------------+----------------+----------+--------------------+--------------------+--------------------+----+-------+---------+-----------+----+----------------+--------+-------------+-------+-------------+---------+--------------+--------------------------+----------------------+------------------+--------------------+--------------------+-------------+---------+----------+----+-----+----+------+
# |CallNumber|UnitID|IncidentNumber|        CallType| WatchDate|CallFinalDisposition|       AvailableDtTm|             Address|City|Zipcode|Battalion|StationArea| Box|OriginalPriority|Priority|FinalPriority|ALSUnit|CallTypeGroup|NumAlarms|      UnitType|UnitSequenceInCallDispatch|FirePreventionDistrict|SupervisorDistrict|        Neighborhood|            Location|        RowID|    Delay|      Date|Year|Month|Week|Season|
# +----------+------+--------------+----------------+----------+--------------------+--------------------+--------------------+----+-------+---------+-----------+----+----------------+--------+-------------+-------+-------------+---------+--------------+--------------------------+----------------------+------------------+--------------------+--------------------+-------------+---------+----------+----+-----+----+------+
# |  20110016|   T13|       2003235|  Structure Fire|01/10/2002|               Other|01/11/2002 01:51:...|2000 Block of CAL...|  SF|  94109|      B04|         38|3362|               3|       3|            3|  false|         NULL|        1|         TRUCK|                         2|                     4|                 5|     Pacific Heights|(37.7895840679362...|020110016-T13|     2.95|2002-01-01|2002|    1|   1|Winter|
# |  20110022|   M17|       2003241|Medical Incident|01/10/2002|               Other|01/11/2002 03:01:...|0 Block of SILVER...|  SF|  94124|      B10|         42|6495|               3|       3|            3|   true|         NULL|        1|         MEDIC|                         1|                    10|                10|Bayview Hunters P...|(37.7337623673897...|020110022-M17|      4.7|2002-01-01|2002|    1|   1|Winter|
# %%
#Give top five fire call types for every season of selected year (seasons are like Spring, summer, fall, winter etc)
from pyspark.sql.window import Window
from pyspark.sql.functions import rank
filtered_data = clean_df.filter(col('Year') == 2018)
window_spec = Window.partitionBy('Season').orderBy(col('count').desc())
ranked_data = filtered_data.groupBy('Season', 'CallType').count().withColumn("rank", rank().over(window_spec))
top_five_in_each_season = ranked_data.filter(col('rank') <= 5)
top_five_in_each_season.show()
# Out:
# +------+-----------------+-----+----+
# |Season|         CallType|count|rank|
# +------+-----------------+-----+----+
# |Winter| Medical Incident| 7004|   1|
# |Winter|           Alarms| 1144|   2|
# |Winter|   Structure Fire|  906|   3|
# |Winter|Traffic Collision|  433|   4|
# |Winter|     Outside Fire|  153|   5|
# +------+-----------------+-----+----+

# %%
from pyspark.sql import functions as F
import matplotlib.pyplot as plt
#Whether fire type calls are seasonal?

monthly_call_counts = clean_df.groupBy('Year', 'Season').count().orderBy('Year', 'Season')
monthly_call_counts_pd = monthly_call_counts.toPandas()
plt.figure(figsize=(12, 6))
plt.plot(monthly_call_counts_pd['Year'].astype(str) + '-' + monthly_call_counts_pd['Season'].astype(str), monthly_call_counts_pd['count'], marker='o')
plt.title('Monthly Fire Call Counts Over Time')
plt.xlabel('Year-Season')
plt.ylabel('Call Count')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
#What months within the year 2018 saw the highest number of fire calls
filtered_data = clean_df.filter(col('Year') == 2018)
monthly_call_counts = filtered_data.groupBy('Month').count()
max_calls = monthly_call_counts.agg({"count": "max"}).collect()[0][0]
top_months = monthly_call_counts.filter(col("count") == max_calls)
top_months.show()
# Out:
# +-----+-----+
# |Month|count|
# +-----+-----+
# |    1|10136|
# +-----+-----+

# %%
#Find which type of fire call is major calltype in each year
yearly_call_counts = clean_df.groupBy('Year', 'CallType').count()
major_call_type_by_year = yearly_call_counts.groupBy('Year').agg(max('count').alias('MaxCount'))
major_call_type_details = yearly_call_counts.join(
    major_call_type_by_year,
    (yearly_call_counts['Year'] == major_call_type_by_year['Year']) & (yearly_call_counts['count'] == major_call_type_by_year['MaxCount']),
    'inner'
)
result = major_call_type_details.select(col('Year'), 'CallType', 'MaxCount')
result.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aa6c3f7dff57> in <cell line: 2>()
#       1 #Find which type of fire call is major calltype in each year
# ----> 2 yearly_call_counts = clean_df.groupBy('Year', 'CallType').count()
#       3 major_call_type_by_year = yearly_call_counts.groupBy('Year').agg(max('count').alias('MaxCount'))
#       4 major_call_type_details = yearly_call_counts.join(
#       5     major_call_type_by_year,
#
# NameError: name 'clean_df' is not defined

# %%
#Find out average delay in response for each call type
average_delay_by_call_type = clean_df.groupBy('CallType').agg(avg('Delay').alias('AverageDelay'))
average_delay_by_call_type.show()
# Out:
# +--------------------+------------------+
# |            CallType|      AverageDelay|
# +--------------------+------------------+
# |Elevator / Escala...| 4.337821933487857|
# |         Marine Fire| 6.928571314285715|
# |  Aircraft Emergency|3.7731481500000004|
# |Confined Space / ...| 6.915384576923078|
# |      Administrative|12.261111333333332|
# |              Alarms|3.5427290545084076|
# |Odor (Strange / U...| 4.947959182000003|
# |Citizen Assist / ...| 5.473342576604596|
# |              HazMat| 7.527016126612902|
# |Watercraft in Dis...| 6.886904817857142|
# |           Explosion| 4.110674168539326|
# |           Oil Spill| 4.977777761904762|
# |        Vehicle Fire|3.9039227134074928|
# |  Suspicious Package|6.5766667199999995|
# |Extrication / Ent...| 4.391666678571427|
# |               Other| 5.505155432421978|
# |        Outside Fire| 4.181948425367714|
# |   Traffic Collision| 3.789132088873234|
# |       Assist Police|26.981903994285716|
# |Gas Leak (Natural...|  4.58339877840314|
# +--------------------+------------------+
# only showing top 20 rows

# %%
#Find which calltype has maximum average delay time.
average_delay_by_call_type = clean_df.groupBy('CallType').agg(avg('Delay').alias('AverageDelay'))
max_average_delay_call_type = average_delay_by_call_type.orderBy(col('AverageDelay').desc()).first()
print("Call Type with Maximum Average Delay:")
print("Call Type:", max_average_delay_call_type['CallType'])
print("Average Delay:", max_average_delay_call_type['AverageDelay'])
# Out:
# Call Type with Maximum Average Delay:
# Call Type: Mutual Aid / Assist Outside Agency
# Average Delay: 38.41666631111111

# %%
#Which neighborhood in San Francisco generated the most fire calls in 2018
neighborhood_call_counts = clean_df.filter((col('Year') == 2018) & (col('Neighborhood').isNotNull())) \
    .groupBy('Neighborhood').count()
max_calls_neighborhood = neighborhood_call_counts.orderBy(col('count').desc()).first()
print("Neighborhood:", max_calls_neighborhood['Neighborhood'])
print("Number of Fire Calls:", max_calls_neighborhood['count'])
# Out:
# Neighborhood: Tenderloin
# Number of Fire Calls: 1393

# %%
#Which neighborhoods had the worst response times to fire calls in 2018?
filtered_data = clean_df.filter((col('Year') == 2018) & (col('Delay').isNotNull()))
neighborhood_response_time = filtered_data.groupBy('Neighborhood').agg(avg('Delay').alias('AverageResponseTime'))
worst_response_time_neighborhoods = neighborhood_response_time.orderBy(col('AverageResponseTime').desc())
worst_response_time_neighborhoods.show()
# Out:
# +--------------------+-------------------+
# |        Neighborhood|AverageResponseTime|
# +--------------------+-------------------+
# |           Chinatown| 6.1903140979057625|
# |            Presidio|  5.829227041449275|
# |     Treasure Island|  5.453703712499999|
# |        McLaren Park|  4.744047642857142|
# |Bayview Hunters P...| 4.6205619568773955|
# |    Presidio Heights|  4.594131472394366|
# |        Inner Sunset|  4.438095199935065|
# |      Inner Richmond|  4.364728682713178|
# |Financial Distric...|  4.344084618290155|
# |      Haight Ashbury|  4.266428599285713|
# |            Seacliff|  4.261111146666667|
# |  West of Twin Peaks|  4.190952390857144|
# |        Potrero Hill|   4.19055555742857|
# |     Pacific Heights|  4.180453718900521|
# |          Tenderloin|   4.10151951659727|
# |Oceanview/Merced/...|  3.947242180719425|
# |           Excelsior| 3.9363993797169807|
# |         North Beach| 3.8892496403463204|
# |           Lakeshore|  3.881551365094342|
# |         Mission Bay| 3.8548689521910124|
# +--------------------+-------------------+
# only showing top 20 rows

# %%
#Find out calltype whose average response delay time is maximum, increases, decreases or has no relation over years
average_delay_by_year_calltype = clean_df.groupBy('Year', 'CallType').agg(avg('Delay').alias('AverageDelay'))
pivoted_data = average_delay_by_year_calltype.groupBy('Year').pivot('CallType').agg(avg('AverageDelay')).na.fill(0)
data = pivoted_data.select('Year', 'CallType').orderBy('Year').toPandas()
plt.plot(data['Year'], data['CallType'])
plt.title('Trend of Average Delay for TypeA Over Years')
plt.xlabel('Year')
plt.ylabel('Average Delay')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-34-7be5b95eb288> in <cell line: 4>()
#       2 average_delay_by_year_calltype = clean_df.groupBy('Year', 'CallType').agg(avg('Delay').alias('AverageDelay'))
#       3 pivoted_data = average_delay_by_year_calltype.groupBy('Year').pivot('CallType').agg(avg('AverageDelay')).na.fill(0)
# ----> 4 data = pivoted_data.select('Year', 'CallType').orderBy('Year').toPandas()
#       5 plt.plot(data['Year'], data['CallType'])
#       6 plt.title('Trend of Average Delay for TypeA Over Years')
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py in select(self, *cols)
#    3221         +-----+---+
#    3222         """
# -> 3223         jdf = self._jdf.select(self._jcols(*cols))
#    3224         return DataFrame(jdf, self.sparkSession)
#    3225
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# -> 1322         return_value = get_return_value(
#    1323             answer, self.gateway_client, self.target_id, self.name)
#    1324
#
# /usr/local/lib/python3.10/dist-packages/pyspark/errors/exceptions/captured.py in deco(*a, **kw)
#     183                 # Hide where the exception came from that shows a non-Pythonic
#     184                 # JVM exception message.
# --> 185                 raise converted from None
#     186             else:
#     187                 raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `CallType` cannot be resolved. Did you mean one of the following? [`Alarms`, `HazMat`, `Other`, `Year`, `Oil Spill`].;
# 'Project [Year#2406, 'CallType]
# +- Project [coalesce(Year#132, cast(0.0 as int)) AS Year#2406, coalesce(nanvl(Administrative#2254, cast(null as double)), cast(0.0 as double)) AS Administrative#2407, coalesce(nanvl(Aircraft Emergency#2255, cast(null as double)), cast(0.0 as double)) AS Aircraft Emergency#2408, coalesce(nanvl(Alarms#2256, cast(null as double)), cast(0.0 as double)) AS Alarms#2409, coalesce(nanvl(Assist Police#2257, cast(null as double)), cast(0.0 as double)) AS Assist Police#2410, coalesce(nanvl(Citizen Assist / Service Call#2258, cast(null as double)), cast(0.0 as double)) AS Citizen Assist / Service Call#2411, coalesce(nanvl(Confined Space / Structure Collapse#2259, cast(null as double)), cast(0.0 as double)) AS Confined Space / Structure Collapse#2412, coalesce(nanvl(Electrical Hazard#2260, cast(null as double)), cast(0.0 as double)) AS Electrical Hazard#2413, coalesce(nanvl(Elevator / Escalator Rescue#2261, cast(null as double)), cast(0.0 as double)) AS Elevator / Escalator Rescue#2414, coalesce(nanvl(Explosion#2262, cast(null as double)), cast(0.0 as double)) AS Explosion#2415, coalesce(nanvl(Extrication / Entrapped (Machinery, Vehicle)#2263, cast(null as double)), cast(0.0 as double)) AS Extrication / Entrapped (Machinery, Vehicle)#2416, coalesce(nanvl(Fuel Spill#2264, cast(null as double)), cast(0.0 as double)) AS Fuel Spill#2417, coalesce(nanvl(Gas Leak (Natural and LP Gases)#2265, cast(null as double)), cast(0.0 as double)) AS Gas Leak (Natural and LP Gases)#2418, coalesce(nanvl(H...
#    +- Project [Year#132, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[0] AS Administrative#2254, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[1] AS Aircraft Emergency#2255, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[2] AS Alarms#2256, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[3] AS Assist Police#2257, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[4] AS Citizen Assist / Service Call#2258, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[5] AS Confined Space / Structure Collapse#2259, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[6] AS Electrical Hazard#2260, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[7] AS Elevator / Escalator Rescue#2261, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[8] AS Explosion#2262, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[9] AS Extrication / Entrapped (Machinery, Vehicle)#2263, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[10] AS Fuel Spill#2264, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[11] AS Gas Leak (Natural and LP Gases)#2265, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[12] AS HazMat#2266, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[13] AS High Angle Rescue#2267, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[14] AS Industrial Accidents#2268, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[15] AS Marine Fire#2269, __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253[16] AS Medical Incident#2270, __p...
#       +- Aggregate [Year#132], [Year#132, pivotfirst(CallType#20, avg(AverageDelay)#2191, Administrative, Aircraft Emergency, Alarms, Assist Police, Citizen Assist / Service Call, Confined Space / Structure Collapse, Electrical Hazard, Elevator / Escalator Rescue, Explosion, Extrication / Entrapped (Machinery, Vehicle), Fuel Spill, Gas Leak (Natural and LP Gases), HazMat, High Angle Rescue, Industrial Accidents, Marine Fire, Medical Incident, Mutual Aid / Assist Outside Agency, Odor (Strange / Unknown), Oil Spill, Other, Outside Fire, Smoke Investigation (Outside), Structure Fire, Suspicious Package, Traffic Collision, Train / Rail Incident, Vehicle Fire, Water Rescue, Watercraft in Distress, 0, 0) AS __pivot_avg(AverageDelay) AS `avg(AverageDelay)`#2253]
#          +- Aggregate [Year#132, CallType#20], [Year#132, CallType#20, avg(AverageDelay#2178) AS avg(AverageDelay)#2191]
#             +- Aggregate [Year#132, CallType#20], [Year#132, CallType#20, avg(Delay#44) AS AverageDelay#2178]
#                +- Project [CallNumber#17, UnitID#18, IncidentNumber#19, CallType#20, WatchDate#22, CallFinalDisposition#23, AvailableDtTm#24, Address#25, City#26, Zipcode#27, Battalion#28, StationArea#29, Box#30, OriginalPriority#31, Priority#32, FinalPriority#33, ALSUnit#34, CallTypeGroup#35, NumAlarms#36, UnitType#37, UnitSequenceInCallDispatch#38, FirePreventionDistrict#39, SupervisorDistrict#40, Neighborhood#41, ... 8 more fields]
#                   +- Project [CallNumber#17, UnitID#18, IncidentNumber#19, CallType#20, WatchDate#22, CallFinalDisposition#23, AvailableDtTm#24, Address#25, City#26, Zipcode#27, Battalion#28, StationArea#29, Box#30, OriginalPriority#31, Priority#32, FinalPriority#33, ALSUnit#34, CallTypeGroup#35, NumAlarms#36, UnitType#37, UnitSequenceInCallDispatch#38, FirePreventionDistrict#39, SupervisorDistrict#40, Neighborhood#41, ... 7 more fields]
#                      +- Project [CallNumber#17, UnitID#18, IncidentNumber#19, CallType#20, WatchDate#22, CallFinalDisposition#23, AvailableDtTm#24, Address#25, City#26, Zipcode#27, Battalion#28, StationArea#29, Box#30, OriginalPriority#31, Priority#32, FinalPriority#33, ALSUnit#34, CallTypeGroup#35, NumAlarms#36, UnitType#37, UnitSequenceInCallDispatch#38, FirePreventionDistrict#39, SupervisorDistrict#40, Neighborhood#41, ... 6 more fields]
#                         +- Project [CallNumber#17, UnitID#18, IncidentNumber#19, CallType#20, WatchDate#22, CallFinalDisposition#23, AvailableDtTm#24, Address#25, City#26, Zipcode#27, Battalion#28, StationArea#29, Box#30, OriginalPriority#31, Priority#32, FinalPriority#33, ALSUnit#34, CallTypeGroup#35, NumAlarms#36, UnitType#37, UnitSequenceInCallDispatch#38, FirePreventionDistrict#39, SupervisorDistrict#40, Neighborhood#41, ... 5 more fields]
#                            +- Project [CallNumber#17, UnitID#18, IncidentNumber#19, CallType#20, WatchDate#22, CallFinalDisposition#23, AvailableDtTm#24, Address#25, City#26, Zipcode#27, Battalion#28, StationArea#29, Box#30, OriginalPriority#31, Priority#32, FinalPriority#33, ALSUnit#34, CallTypeGroup#35, NumAlarms#36, UnitType#37, UnitSequenceInCallDispatch#38, FirePreventionDistrict#39, SupervisorDistrict#40, Neighborhood#41, ... 4 more fields]
#                               +- Project [CallNumber#17, UnitID#18, IncidentNumber#19, CallType#20, CallDate#21, WatchDate#22, CallFinalDisposition#23, AvailableDtTm#24, Address#25, City#26, Zipcode#27, Battalion#28, StationArea#29, Box#30, OriginalPriority#31, Priority#32, FinalPriority#33, ALSUnit#34, CallTypeGroup#35, NumAlarms#36, UnitType#37, UnitSequenceInCallDispatch#38, FirePreventionDistrict#39, SupervisorDistrict#40, ... 5 more fields]
#                                  +- Relation [CallNumber#17,UnitID#18,IncidentNumber#19,CallType#20,CallDate#21,WatchDate#22,CallFinalDisposition#23,AvailableDtTm#24,Address#25,City#26,Zipcode#27,Battalion#28,StationArea#29,Box#30,OriginalPriority#31,Priority#32,FinalPriority#33,ALSUnit#34,CallTypeGroup#35,NumAlarms#36,UnitType#37,UnitSequenceInCallDispatch#38,FirePreventionDistrict#39,SupervisorDistrict#40,... 4 more fields] csv

# %%
#For each year find out which city has more calltype

call_type_by_city_year = clean_df.groupBy('Year', 'CallType', 'City').count()
window_spec = Window.partitionBy('Year', 'CallType').orderBy(col('count').desc())
max_call_type_by_city_year = call_type_by_city_year.withColumn('rank', rank().over(window_spec))
max_calls_by_city_year = max_call_type_by_city_year.filter(col('rank') == 1)
max_calls_by_city_year.show()
# Out:
# +----+--------------------+----+-----+----+
# |Year|            CallType|City|count|rank|
# +----+--------------------+----+-----+----+
# |2000|  Aircraft Emergency| SFO|    3|   1|
# |2000|              Alarms|  SF|  620|   1|
# |2000|Citizen Assist / ...|  SF|  124|   1|
# |2000|   Electrical Hazard|  SF|    6|   1|
# |2000|Elevator / Escala...|  SF|   15|   1|
# |2000|          Fuel Spill|  SF|   12|   1|
# |2000|Gas Leak (Natural...|  SF|   11|   1|
# |2000|Industrial Accidents|  SF|    4|   1|
# |2000|    Medical Incident|  SF| 3399|   1|
# |2000|Odor (Strange / U...|  SF|   19|   1|
# |2000|           Oil Spill|  SF|    5|   1|
# |2000|               Other|  SF|   99|   1|
# |2000|        Outside Fire|  SF|   67|   1|
# |2000|Smoke Investigati...|  SF|   12|   1|
# |2000|      Structure Fire|  SF| 1002|   1|
# |2000|  Suspicious Package|  SF|    1|   1|
# |2000|Train / Rail Inci...|  SF|    2|   1|
# |2000|        Vehicle Fire|  SF|   30|   1|
# |2000|        Water Rescue|  SF|    7|   1|
# |2001|  Aircraft Emergency| SFO|    4|   1|
# +----+--------------------+----+-----+----+
# only showing top 20 rows

# %%
#for every year find count of calltypes for 5 cities which has more calls.
call_type_by_city_year = clean_df.groupBy('Year', 'City', 'CallType').count()
window_spec = Window.partitionBy('Year').orderBy(col('count').desc())
ranked_cities_by_year = call_type_by_city_year.withColumn('rank', row_number().over(window_spec))
top5_cities_by_year = ranked_cities_by_year.filter(col('rank') <= 5)
result = top5_cities_by_year.groupBy('Year', 'CallType').count()
result.show()
# Out:
# +----+--------------------+-----+
# |Year|            CallType|count|
# +----+--------------------+-----+
# |2000|    Medical Incident|    1|
# |2000|      Structure Fire|    1|
# |2000|              Alarms|    1|
# |2000|Citizen Assist / ...|    1|
# |2000|               Other|    1|
# |2001|    Medical Incident|    1|
# |2001|      Structure Fire|    1|
# |2001|              Alarms|    1|
# |2001|               Other|    1|
# |2001|Citizen Assist / ...|    1|
# |2002|    Medical Incident|    1|
# |2002|      Structure Fire|    1|
# |2002|              Alarms|    1|
# |2002|               Other|    1|
# |2002|Citizen Assist / ...|    1|
# |2003|    Medical Incident|    1|
# |2003|      Structure Fire|    1|
# |2003|              Alarms|    1|
# |2003|   Traffic Collision|    1|
# |2003|Citizen Assist / ...|    1|
# +----+--------------------+-----+
# only showing top 20 rows

# %%
#Is there a correlation between neighborhood, zip code, and number of fire calls
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.types import DoubleType
from pyspark.ml.stat import Correlation
from pyspark.ml.feature import VectorAssembler

# Create a Spark session
aggregated_data = clean_df.groupBy('Neighborhood', 'ZipCode').count()
pivoted_data = aggregated_data.groupBy('Neighborhood').pivot('ZipCode').count().na.fill(0)
assembler = VectorAssembler(inputCols=pivoted_data.columns[1:], outputCol="features")
feature_vector = assembler.transform(pivoted_data)
correlation_matrix = Correlation.corr(feature_vector, "features", method="pearson")
correlation_array = correlation_matrix.collect()[0]["pearson(features)"].toArray()
for i, neighborhood in enumerate(pivoted_data.select('Neighborhood').rdd.map(lambda x: x[0]).collect()):
    for j, zip_code in enumerate(pivoted_data.columns[1:]):
        correlation = correlation_array[i][j]
        print(f"Correlation between {neighborhood} and {zip_code}: {correlation}")
# Out:
# Correlation between Inner Sunset and null: 1.0
# Correlation between Inner Sunset and 94102: -0.09128709291752768
# Correlation between Inner Sunset and 94103: -0.10846522890932808
# Correlation between Inner Sunset and 94104: -0.05
# Correlation between Inner Sunset and 94105: -0.05
# Correlation between Inner Sunset and 94107: -0.08219949365267865
# Correlation between Inner Sunset and 94108: -0.062017367294604234
# Correlation between Inner Sunset and 94109: -0.09999999999999998
# Correlation between Inner Sunset and 94110: -0.09128709291752768
# Correlation between Inner Sunset and 94111: -0.062017367294604234
# Correlation between Inner Sunset and 94112: 0.22821773229381923
# Correlation between Inner Sunset and 94114: -0.09999999999999998
# Correlation between Lone Mountain/USF and 94123: -0.07692307692307694
# Correlation between Lone Mountain/USF and 94124: -0.1019559237857732
# Correlation between Lone Mountain/USF and 94127: -0.07692307692307694
# Correlation between Lone Mountain/USF and 94129: -0.06201736729460423
# Correlation between Lone Mountain/USF and 94130: -0.04331480818242099
# Correlation between Lone Mountain/USF and 94131: -0.11322770341445958
# Correlation between Lone Mountain/USF and 94132: -0.0899842541331695
# Correlation between Lone Mountain/USF and 94133: 0.5399055247990171
# Correlation between Lone Mountain/USF and 94134: -0.11322770341445958
# Correlation between Lone Mountain/USF and 94158: -0.07692307692307694
# Correlation between Western Addition and null: -0.09999999999999998
# Correlation between Western Addition and 94102: 0.3651483716701107
# Correlation between Western Addition and 94103: -0.054232614454664006
# Correlation between Western Addition and 94104: -0.09999999999999998
# Correlation between Western Addition and 94105: -0.09999999999999998
# Correlation between Western Addition and 94107: -0.16439898730535726
# Correlation between Western Addition and 94108: 0.12403473458920848
# Correlation between Western Addition and 94109: 1.0
# Correlation between Western Addition and 94110: -0.18257418583505533
# Correlation between Western Addition and 94111: -0.12403473458920844
# Correlation between Western Addition and 94112: -0.18257418583505533
# Correlation between Western Addition and 94114: -0.1999999999999999
# Correlation between Western Addition and 94115: 0.3651483716701107
# Correlation between Western Addition and 94116: -0.12403473458920844
# Correlation between Western Addition and 94117: -0.028571428571428522
# Correlation between Western Addition and 94118: -0.1999999999999999
# Correlation between Western Addition and 94121: -0.1450952500220023
# Correlation between Western Addition and 94122: -0.18257418583505533
# Correlation between Western Addition and 94123: 0.37210420376762543
# Correlation between Western Addition and 94124: -0.16439898730535724
# Correlation between Western Addition and 94127: -0.12403473458920844
# Correlation between Western Addition and 94129: -0.09999999999999998
# Correlation between Western Addition and 94130: -0.0698430295769578
# Correlation between Western Addition and 94131: -0.18257418583505533
# Correlation between Western Addition and 94132: -0.1450952500220023
# Correlation between Western Addition and 94133: 0.29019050004400465
# Correlation between Western Addition and 94134: -0.18257418583505533
# Correlation between Western Addition and 94158: -0.12403473458920844
# Correlation between Bernal Heights and null: -0.09128709291752768
# Correlation between Bernal Heights and 94102: -0.16666666666666663
# Correlation between Bernal Heights and 94103: 0.32179795146741913
# Correlation between Bernal Heights and 94104: -0.09128709291752768
# Correlation between Bernal Heights and 94105: -0.09128709291752768
# Correlation between Bernal Heights and 94107: 0.060030022518766435
# Correlation between Bernal Heights and 94108: -0.11322770341445958
# Correlation between Bernal Heights and 94109: -0.18257418583505533
# Correlation between Bernal Heights and 94110: 1.0
# Correlation between Bernal Heights and 94111: -0.11322770341445958
# Correlation between Bernal Heights and 94112: 0.027777777777777794
# Correlation between Bernal Heights and 94114: 0.3651483716701107
# Correlation between Bernal Heights and 94115: -0.16666666666666663
# Correlation between Bernal Heights and 94116: -0.11322770341445958
# Correlation between Bernal Heights and 94117: 2.5970689554584665e-17
# Correlation between Bernal Heights and 94118: -0.18257418583505533
# Correlation between Bernal Heights and 94121: -0.13245323570650436
# Correlation between Bernal Heights and 94122: -0.16666666666666663
# Correlation between Visitacion Valley and 94112: -0.18257418583505533
# Correlation between Visitacion Valley and 94114: 0.48571428571428565
# Correlation between Visitacion Valley and 94115: 0.18257418583505539
# Correlation between Visitacion Valley and 94116: 0.12403473458920848
# Correlation between Visitacion Valley and 94117: 1.0
# Correlation between Visitacion Valley and 94118: 0.14285714285714285
# Correlation between Visitacion Valley and 94121: 0.07254762501100118
# Correlation between Visitacion Valley and 94122: 0.3651483716701107
# Correlation between Visitacion Valley and 94123: -0.12403473458920844
# Correlation between Visitacion Valley and 94124: -0.16439898730535724
# Correlation between Visitacion Valley and 94127: -0.12403473458920844
# Correlation between Visitacion Valley and 94129: -0.09999999999999998
# Correlation between Visitacion Valley and 94130: -0.0698430295769578
# Correlation between Visitacion Valley and 94131: 0.18257418583505539
# Correlation between Visitacion Valley and 94132: -0.1450952500220023
# Correlation between Visitacion Valley and 94133: -0.1450952500220023
# Correlation between Visitacion Valley and 94134: -0.18257418583505533
# Correlation between Visitacion Valley and 94158: -0.12403473458920844
# Correlation between Inner Richmond and null: -0.09999999999999998
# Correlation between Inner Richmond and 94102: -0.18257418583505533
# Correlation between Inner Richmond and 94103: -0.2169304578186561
# Correlation between Inner Richmond and 94104: -0.09999999999999998
# Correlation between Inner Richmond and 94105: -0.09999999999999998
# Correlation between Inner Richmond and 94107: -0.16439898730535726
# Correlation between Inner Richmond and 94108: -0.12403473458920844
# Correlation between Inner Richmond and 94109: -0.1999999999999999
# Correlation between Inner Richmond and 94110: -0.18257418583505533
# Correlation between Inner Richmond and 94111: -0.12403473458920844
# Correlation between Inner Richmond and 94112: -0.18257418583505533
# Correlation between Inner Richmond and 94114: -0.1999999999999999
# Correlation between Inner Richmond and 94115: 0.3651483716701107
# Correlation between Inner Richmond and 94116: -0.12403473458920844
# Correlation between Inner Richmond and 94117: 0.14285714285714285
# Correlation between Inner Richmond and 94118: 1.0
# Correlation between Inner Richmond and 94121: 0.5078333750770081
# Correlation between Inner Richmond and 94122: 0.5477225575051661
# Correlation between Inner Richmond and 94123: 0.12403473458920848
# Correlation between Inner Richmond and 94124: -0.16439898730535724
# Correlation between Inner Richmond and 94127: -0.12403473458920844
# Correlation between Inner Richmond and 94129: 0.4999999999999999
# Correlation between Inner Richmond and 94130: -0.0698430295769578
# Correlation between Inner Richmond and 94131: -0.18257418583505533
# Correlation between Inner Richmond and 94132: -0.1450952500220023
# Correlation between Inner Richmond and 94133: -0.1450952500220023
# Correlation between Inner Richmond and 94134: -0.18257418583505533
# Correlation between Inner Richmond and 94158: -0.12403473458920844
# Correlation between Nob Hill and null: -0.07254762501100118
# Correlation between Nob Hill and 94102: -0.13245323570650436
# Correlation between Nob Hill and 94103: -0.15737789507292677
# Correlation between Nob Hill and 94104: -0.07254762501100118
# Correlation between Nob Hill and 94105: -0.07254762501100118
# Correlation between Nob Hill and 94107: -0.119267560832174
# Correlation between Nob Hill and 94108: -0.0899842541331695
# Correlation between Nob Hill and 94109: -0.1450952500220023
# Correlation between Excelsior and 94107: -0.05741061666394991
# Correlation between Excelsior and 94108: -0.04331480818242099
# Correlation between Excelsior and 94109: -0.0698430295769578
# Correlation between Excelsior and 94110: -0.06375767130633382
# Correlation between Excelsior and 94111: -0.04331480818242099
# Correlation between Excelsior and 94112: -0.06375767130633382
# Correlation between Excelsior and 94114: -0.0698430295769578
# Correlation between Excelsior and 94115: -0.06375767130633382
# Correlation between Excelsior and 94116: -0.04331480818242099
# Correlation between Excelsior and 94117: -0.0698430295769578
# Correlation between Excelsior and 94118: -0.0698430295769578
# Correlation between Excelsior and 94121: -0.050669459193814
# Correlation between Excelsior and 94122: -0.06375767130633382
# Correlation between Excelsior and 94123: -0.04331480818242099
# Correlation between Excelsior and 94124: -0.05741061666394991
# Correlation between Excelsior and 94127: -0.04331480818242099
# Correlation between Excelsior and 94129: -0.03492151478847891
# Correlation between Excelsior and 94130: 1.0
# Correlation between Excelsior and 94131: -0.06375767130633382
# Correlation between Excelsior and 94132: -0.050669459193814
# Correlation between Excelsior and 94133: -0.050669459193814
# Correlation between Excelsior and 94134: -0.06375767130633382
# Correlation between Excelsior and 94158: -0.043314808182421
# Correlation between Twin Peaks and null: -0.09128709291752768
# Correlation between Twin Peaks and 94102: -0.16666666666666663
# Correlation between Twin Peaks and 94103: -0.02475368857441685
# Correlation between Twin Peaks and 94104: -0.09128709291752768
# Correlation between Twin Peaks and 94105: -0.09128709291752768
# Correlation between Twin Peaks and 94107: -0.15007505629691603
# Correlation between Twin Peaks and 94108: -0.11322770341445958
# Correlation between Twin Peaks and 94109: -0.18257418583505533
# Correlation between Twin Peaks and 94110: 0.4166666666666666
# Correlation between Twin Peaks and 94111: -0.11322770341445958
# Correlation between Twin Peaks and 94112: 0.027777777777777794
# Correlation between Twin Peaks and 94114: 0.5477225575051661
# Correlation between Twin Peaks and 94115: -0.16666666666666663
# Correlation between Twin Peaks and 94116: 0.41516824585301854
# Correlation between Twin Peaks and 94117: 0.18257418583505539
# Correlation between Twin Peaks and 94118: -0.18257418583505533
# Correlation between Twin Peaks and 94121: -0.13245323570650439
# Correlation between Twin Peaks and 94122: 0.027777777777777794
# Correlation between Twin Peaks and 94123: -0.11322770341445958
# Correlation between Twin Peaks and 94124: -0.15007505629691603
# Correlation between Twin Peaks and 94127: 0.41516824585301854
# Correlation between Twin Peaks and 94129: -0.09128709291752768
# Correlation between Twin Peaks and 94130: -0.06375767130633382
# Correlation between Twin Peaks and 94131: 1.0
# Correlation between Twin Peaks and 94132: 0.09933992677987831
# Correlation between Twin Peaks and 94133: -0.13245323570650436
# Correlation between Twin Peaks and 94134: -0.16666666666666663
# Correlation between Twin Peaks and 94158: -0.11322770341445958
# Correlation between Seacliff and null: -0.07254762501100118
# Correlation between Seacliff and 94102: -0.13245323570650436
# Correlation between Seacliff and 94103: -0.15737789507292677
# Correlation between Seacliff and 94104: -0.07254762501100118
# Correlation between Seacliff and 94105: -0.07254762501100118
# Correlation between Seacliff and 94107: -0.119267560832174
# Correlation between Seacliff and 94108: -0.0899842541331695
# Correlation between Seacliff and 94109: -0.1450952500220023
# Correlation between Seacliff and 94110: -0.13245323570650436
# Correlation between Seacliff and 94111: -0.0899842541331695
# Correlation between Seacliff and 94112: 0.331133089266261
# Correlation between Seacliff and 94114: -0.1450952500220023
# Correlation between Seacliff and 94115: -0.13245323570650436
# Correlation between Seacliff and 94116: 0.5399055247990171
# Correlation between Seacliff and 94117: -0.1450952500220023
# Correlation between Seacliff and 94118: -0.1450952500220023
# Correlation between Seacliff and 94121: -0.10526315789473686
# Correlation between Seacliff and 94122: 0.09933992677987831
# Correlation between Seacliff and 94123: -0.0899842541331695
# Correlation between Seacliff and 94124: -0.119267560832174
# Correlation between Seacliff and 94127: 0.5399055247990171
# Correlation between Seacliff and 94129: -0.07254762501100118
# Correlation between Seacliff and 94130: -0.050669459193814
# Correlation between Seacliff and 94131: 0.09933992677987831
# Correlation between Seacliff and 94132: 1.0
# Correlation between Seacliff and 94133: -0.10526315789473686
# Correlation between Seacliff and 94134: -0.13245323570650439
# Correlation between Seacliff and 94158: -0.08998425413316952
# Correlation between Sunset/Parkside and null: -0.07254762501100118
# Correlation between Sunset/Parkside and 94102: 0.09933992677987831
# Correlation between Sunset/Parkside and 94103: -0.15737789507292677
# Correlation between Sunset/Parkside and 94104: 0.308327406296755
# Correlation between Sunset/Parkside and 94105: -0.07254762501100118
# Correlation between Sunset/Parkside and 94107: -0.119267560832174
# Correlation between Sunset/Parkside and 94108: 0.5399055247990171
# Correlation between Sunset/Parkside and 94109: 0.29019050004400465
# Correlation between Sunset/Parkside and 94110: -0.13245323570650436
# Correlation between Sunset/Parkside and 94111: 0.5399055247990171
# Correlation between Sunset/Parkside and 94112: -0.13245323570650436
# Correlation between Sunset/Parkside and 94114: -0.1450952500220023
# Correlation between Sunset/Parkside and 94115: -0.13245323570650436
# Correlation between Sunset/Parkside and 94116: -0.0899842541331695
# Correlation between Sunset/Parkside and 94117: -0.1450952500220023
# Correlation between Sunset/Parkside and 94118: -0.1450952500220023
# Correlation between Sunset/Parkside and 94121: -0.10526315789473686
# Correlation between Sunset/Parkside and 94122: -0.13245323570650436
# Correlation between Sunset/Parkside and 94123: -0.0899842541331695
# Correlation between Sunset/Parkside and 94124: -0.119267560832174
# Correlation between Sunset/Parkside and 94127: -0.0899842541331695
# Correlation between Sunset/Parkside and 94129: -0.07254762501100118
# Correlation between Sunset/Parkside and 94130: -0.050669459193814
# Correlation between Sunset/Parkside and 94131: -0.13245323570650436
# Correlation between Sunset/Parkside and 94132: -0.10526315789473686
# Correlation between Sunset/Parkside and 94133: 1.0
# Correlation between Sunset/Parkside and 94134: -0.13245323570650439
# Correlation between Sunset/Parkside and 94158: -0.08998425413316952
# Correlation between Presidio Heights and null: 0.5477225575051661
# Correlation between Presidio Heights and 94102: -0.16666666666666663
# Correlation between Presidio Heights and 94103: -0.19802950859533486
# Correlation between Presidio Heights and 94104: -0.09128709291752768
# Correlation between Presidio Heights and 94105: -0.09128709291752768
# Correlation between Presidio Heights and 94107: 0.060030022518766435
# Correlation between Presidio Heights and 94108: -0.11322770341445958
# Correlation between Presidio Heights and 94109: -0.18257418583505533
# Correlation between Presidio Heights and 94110: -0.16666666666666663
# Correlation between Presidio Heights and 94111: -0.11322770341445958
# Correlation between Presidio Heights and 94112: 0.2222222222222222
# Correlation between Presidio Heights and 94114: -0.18257418583505533
# Correlation between Presidio Heights and 94115: -0.16666666666666663
# Correlation between Presidio Heights and 94116: -0.11322770341445958
# Correlation between Presidio Heights and 94117: -0.18257418583505533
# Correlation between Presidio Heights and 94118: -0.18257418583505533
# Correlation between Presidio Heights and 94121: -0.13245323570650439
# Correlation between Presidio Heights and 94122: -0.16666666666666663
# Correlation between Presidio Heights and 94123: -0.11322770341445958
# Correlation between Presidio Heights and 94124: 0.48024018015013137
# Correlation between Presidio Heights and 94127: -0.11322770341445958
# Correlation between Presidio Heights and 94129: -0.09128709291752768
# Correlation between Presidio Heights and 94130: -0.06375767130633382
# Correlation between Presidio Heights and 94131: -0.16666666666666663
# Correlation between Presidio Heights and 94132: -0.13245323570650439
# Correlation between Presidio Heights and 94133: -0.13245323570650439
# Correlation between Presidio Heights and 94134: 1.0
# Correlation between Presidio Heights and 94158: 0.15097027121927947
# Correlation between Portola and null: 0.37210420376762543
# Correlation between Portola and 94102: -0.11322770341445958
# Correlation between Portola and 94103: 0.3363363969981563
# Correlation between Portola and 94104: -0.062017367294604234
# Correlation between Portola and 94105: -0.062017367294604234
# Correlation between Portola and 94107: 0.4689972494145568
# Correlation between Portola and 94108: -0.07692307692307694
# Correlation between Portola and 94109: -0.12403473458920844
# Correlation between Portola and 94110: 0.15097027121927947
# Correlation between Portola and 94111: -0.07692307692307694
# Correlation between Portola and 94112: -0.11322770341445958
# Correlation between Portola and 94114: -0.12403473458920844
# Correlation between Portola and 94115: -0.11322770341445958
# Correlation between Portola and 94116: -0.07692307692307694
# Correlation between Portola and 94117: -0.12403473458920844
# Correlation between Portola and 94118: -0.12403473458920844
# Correlation between Portola and 94121: -0.08998425413316952
# Correlation between Portola and 94122: -0.11322770341445958
# Correlation between Portola and 94123: -0.07692307692307694
# Correlation between Portola and 94124: 0.4689972494145568
# Correlation between Portola and 94127: -0.07692307692307694
# Correlation between Portola and 94129: -0.062017367294604234
# Correlation between Portola and 94130: -0.043314808182421
# Correlation between Portola and 94131: -0.11322770341445958
# Correlation between Portola and 94132: -0.08998425413316952
# Correlation between Portola and 94133: -0.08998425413316952
# Correlation between Portola and 94134: 0.15097027121927947
# Correlation between Portola and 94158: 1.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-a6712f31dd09> in <cell line: 15>()
#      15 for i, neighborhood in enumerate(pivoted_data.select('Neighborhood').rdd.map(lambda x: x[0]).collect()):
#      16     for j, zip_code in enumerate(pivoted_data.columns[1:]):
# ---> 17         correlation = correlation_array[i][j]
#      18         print(f"Correlation between {neighborhood} and {zip_code}: {correlation}")
#
# IndexError: index 28 is out of bounds for axis 0 with size 28
